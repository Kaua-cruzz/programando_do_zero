# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaua-cruzz/programando_do_zero/blob/main/Linguagem_de_programa%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #U1_A1

# %%
print('hello world')
# Out:
# hello world

# %%
#2. criando variaveis
x = 10
nome = 'anderson'
nota = 8.75
fez_inscricao = True

# %%
print (x)
print(nome)
print(nota)
print(fez_inscricao)
# Out:
# 10
# anderson
# 8.75
# True

# %%
print (type (x))
print(type(nome))
print(type(nota))
print(type(fez_inscricao))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'bool'>

# %%
nome = input("digite seu nome: ")
# Out:
# digite seu nome: rayane

# %%
print(f"olá {nome}, bem vindo à disciplina de programação")
# Out:
# olá rayane, bem vindo à disciplina de programação

# %%
nota_1 = int(input("digite a nota 1: "))
nota_2 = int(input("digite a nota 2: "))
nota_3 = int(input("digite a nota 3: "))
nota_4 = int(input("digite a nota 4: "))
# Out:
# digite a nota 1: 9
# digite a nota 2: 6
# digite a nota 3: 2
# digite a nota 4: 5

# %%
media = (nota_1+nota_2+nota_3+nota_4) / 4

# %%
print (media)
# Out:
# 5.5

# %%
if media >= 5:
  print('aprovado')
else:
  print('reprovado')
# Out:
# aprovado
